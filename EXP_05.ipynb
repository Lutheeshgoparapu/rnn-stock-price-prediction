# %% [markdown]
# <a href="https://colab.research.google.com/github/Lutheeshgoparapu/rnn-stock-price-prediction/blob/main/EXP_05.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from keras import layers
from keras.models import Sequential

# %%
dataset_train = pd.read_csv('trainset.csv')

# %%
dataset_train.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
dataset_train.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2013-01-02  357.385559  361.151062  355.959839  359.288177  359.288177
# 1  2013-01-03  360.122742  363.600128  358.031342  359.496826  359.496826
# 2  2013-01-04  362.313507  368.339294  361.488861  366.600616  366.600616
# 3  2013-01-07  365.348755  367.301056  362.929504  365.001007  365.001007
# 4  2013-01-08  365.393463  365.771027  359.874359  364.280701  364.280701
#
#     Volume
# 0  5115500
# 1  4666500
# 2  5562800
# 3  3332900
# 4  3373900
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Open'].plot(kind='hist', bins=20, title='Open')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['High'].plot(kind='hist', bins=20, title='High')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
train_set = dataset_train.iloc[:,1:2].values

# %%
type(train_set)
# Out:
# numpy.ndarray

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(train_set)

# %%
training_set_scaled.shape
# Out:
# (1259, 1)

# %%
X_train_array = []
y_train_array = []
for i in range(60, 1259):
  X_train_array.append(training_set_scaled[i-60:i,0])
  y_train_array.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train_array), np.array(y_train_array)
X_train1 = X_train.reshape((X_train.shape[0], X_train.shape[1],1))

# %%
X_train.shape
# Out:
# (1199, 60)

# %%
length = 60
n_features = 1

# %%
model = Sequential()

model.add(layers.SimpleRNN(50,input_shape=(length,n_features)))
model.add(layers.Dense(1))

# %%
model.compile(optimizer='adam', loss='mse')

# %%
print("Name: G.Lutheesh      Register Number:  212221230029        ")
model.summary()
# Out:
# Name: G.Lutheesh      Register Number:  212221230029
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  simple_rnn (SimpleRNN)      (None, 50)                2600
#
#  dense (Dense)               (None, 1)                 51
#
# ...
# Total params: 2651 (10.36 KB)
# Trainable params: 2651 (10.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.fit(X_train1,y_train,epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 2s 17ms/step - loss: 0.0539
# Epoch 2/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0017
# Epoch 3/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0013
# Epoch 4/100
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0012
# Epoch 5/100
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0010
# Epoch 6/100
# 38/38 [==============================] - 0s 10ms/step - loss: 9.6013e-04
# Epoch 7/100
# 38/38 [==============================] - 0s 10ms/step - loss: 9.7727e-04
# Epoch 8/100
# 38/38 [==============================] - 0s 10ms/step - loss: 8.8760e-04
# Epoch 9/100
# 38/38 [==============================] - 0s 10ms/step - loss: 7.7686e-04
# Epoch 10/100
# 38/38 [==============================] - 0s 10ms/step - loss: 8.3627e-04
# Epoch 11/100
# 38/38 [==============================] - 0s 10ms/step - loss: 7.2424e-04
# Epoch 12/100
# ...

# %%
dataset_test = pd.read_csv('testset.csv')

# %%
test_set = dataset_test.iloc[:,1:2].values

# %%
test_set.shape
# Out:
# (125, 1)

# %%
dataset_total = pd.concat((dataset_train['Open'],dataset_test['Open']),axis=0)

# %%
inputs = dataset_total.values
inputs = inputs.reshape(-1,1)
inputs_scaled=sc.transform(inputs)
X_test = []
for i in range(60,1384):
  X_test.append(inputs_scaled[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test,(X_test.shape[0], X_test.shape[1],1))

# %%
X_test.shape
# Out:
# (1324, 60, 1)

# %%
predicted_stock_price_scaled = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price_scaled)
# Out:
# 42/42 [==============================] - 0s 6ms/step

# %%
print("Name:G.Lutheesh           Register Number: 212221230029    ")
plt.plot(np.arange(0,1384),inputs, color='red', label = 'Test(Real) Google stock price')
plt.plot(np.arange(60,1384),predicted_stock_price, color='blue', label = 'Predicted Google stock price')
plt.title('Google Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()
# Out:
# Name:G.Lutheesh           Register Number: 212221230029
